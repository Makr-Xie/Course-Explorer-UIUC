# %%
from flask import Flask, jsonify, request, render_template, send_from_directory
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
import pandas as pd
from flask_cors import CORS
import os
import json

uri = "mongodb+srv://CSGROUP222:BAsSG1pOcss7KmN0@cluster222.vduea3l.mongodb.net/?retryWrites=true&w=majority&appName=Cluster222"

client = MongoClient(uri, server_api=ServerApi('1'))

# %%
db = client['Course_Data']  # Access the database
collection = db['2020-2023']  # Access the collection
courses_cursor = collection.find().limit(10)
courses_list = list(courses_cursor)
for course in courses_list:
    course['_id'] = str(course['_id'])

# Convert the list to JSON (for demonstration purposes)
json_data = json.dumps(courses_list, indent=4)
print(json_data)
# Out:
# [
#     {
#         "_id": "6602465bc11cca4c26fff5e5",
#         "Subject": "AAS",
#         "Course": 100,
#         "Course Title": "Intro Asian American Studies",
#         "Average Grade": 3.53,
#         "Primary Instructor": "Lee, Sang S",
#         "Professor Rating": 3.5
#     },
#     {
#         "_id": "6602465bc11cca4c26fff5e6",
#         "Subject": "AAS",
#         "Course": 100,
#         "Course Title": "Intro Asian American Studies",
#         "Average Grade": 3.15,
#         "Primary Instructor": "Thomas, Merin A",
#         "Professor Rating": ""
#     },
#     {
#         "_id": "6602465bc11cca4c26fff5e7",
#         "Subject": "AAS",
#         "Course": 215,
#         "Course Title": "US Citizenship Comparatively",
#         "Average Grade": 3.69,
#         "Primary Instructor": "Compoc, Kimberly M",
#         "Professor Rating": ""
#     },
#     {
#         "_id": "6602465bc11cca4c26fff5e8",
#         "Subject": "ACCY",
#         "Course": 200,
#         "Course Title": "Fundamentals of Accounting",
#         "Average Grade": 3.11,
#         "Primary Instructor": "Silhan, Peter A",
#         "Professor Rating": 1.6
#     },
#     {
#         "_id": "6602465bc11cca4c26fff5e9",
#         "Subject": "ACCY",
#         "Course": 200,
#         "Course Title": "Fundamentals of Accounting",
#         "Average Grade": 3.89,
#         "Primary Instructor": "",
#         "Professor Rating": ""
#     },
#     {
#         "_id": "6602465bc11cca4c26fff5ea",
#         "Subject": "ABE",
#         "Course": 226,
#         "Course Title": "ABE Principles: Bioprocessing",
#         "Average Grade": 3.33,
#         "Primary Instructor": "Singh, Vijay",
#         "Professor Rating": 3.3
#     },
#     {
#         "_id": "6602465bc11cca4c26fff5eb",
#         "Subject": "ACCY",
#         "Course": 301,
#         "Course Title": "Atg Measurement & Disclosure",
#         "Average Grade": 3.38,
#         "Primary Instructor": "Davis, Gregory L",
#         "Professor Rating": 4.8
#     },
#     {
#         "_id": "6602465bc11cca4c26fff5ec",
#         "Subject": "ACCY",
#         "Course": 301,
#         "Course Title": "Atg Measurement & Disclosure",
#         "Average Grade": 3.23,
#         "Primary Instructor": "Davis, Gregory L",
#         "Professor Rating": 4.8
#     },
#     {
#         "_id": "6602465bc11cca4c26fff5ed",
#         "Subject": "ABE",
#         "Course": 469,
#         "Course Title": "Industry-Linked Design Project",
#         "Average Grade": 3.66,
#         "Primary Instructor": "Witmer, Ann-Perry",
#         "Professor Rating": 0.0
#     },
#     {
#         "_id": "6602465bc11cca4c26fff5ee",
#         "Subject": "ABE",
#         "Course": 425,
#         "Course Title": "Engrg Measurement Systems",
#         "Average Grade": 3.75,
#         "Primary Instructor": "Grift, Tony E",
#         "Professor Rating": 2.7
#     }
# ]

# %%
uri = "mongodb+srv://CSGROUP222:BAsSG1pOcss7KmN0@cluster222.vduea3l.mongodb.net/?retryWrites=true&w=majority&appName=Cluster222"
client = MongoClient(uri, server_api=ServerApi('1'))

db = client['Course_Data']  # Access the database
allCourses = db['2020-2023'] # Access to all courses
geneds = db['geneds']   # Access to GenEds


@app.route('/')
def index():
  return render_template("index.html")


## all courses request
## Right Now it will return the first 10
@app.route('/courses', methods=['GET'])
def get_courses():
    courses_cursor = allCourses.find().limit(10)
    courses_list = list(courses_cursor)
    for course in courses_list:
        course['_id'] = str(course['_id'])
    return jsonify(courses_list)
